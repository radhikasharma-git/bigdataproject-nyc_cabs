# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Parquet Reader").getOrCreate()


#2019 data
df_2019_02 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-02.parquet", header=True, inferSchema=True)
df_2019_03 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-03.parquet", header=True, inferSchema=True)
df_2019_04 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-04.parquet", header=True, inferSchema=True)
df_2019_05 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-05.parquet", header=True, inferSchema=True)
df_2019_06 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-06.parquet", header=True, inferSchema=True)
df_2019_07 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-07.parquet", header=True, inferSchema=True)
df_2019_08 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-08.parquet", header=True, inferSchema=True)
df_2019_09 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-09.parquet", header=True, inferSchema=True)
df_2019_10 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-10.parquet", header=True, inferSchema=True)
df_2019_11 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-11.parquet", header=True, inferSchema=True)
df_2019_12 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-12.parquet", header=True, inferSchema=True)


# #2020 data
# df_2020_01 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-01.parquet", header=True, inferSchema=True)
# df_2020_02 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-02.parquet", header=True, inferSchema=True)
# df_2020_03 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-03.parquet", header=True, inferSchema=True)
# df_2020_04 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-04.parquet", header=True, inferSchema=True)
# df_2020_05 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-05.parquet", header=True, inferSchema=True)
# df_2020_06 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-06.parquet", header=True, inferSchema=True)
# df_2020_07 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-07.parquet", header=True, inferSchema=True)
# df_2020_08 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-08.parquet", header=True, inferSchema=True)
# df_2020_09 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-09.parquet", header=True, inferSchema=True)
# df_2020_10 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-10.parquet", header=True, inferSchema=True)
# df_2020_11 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-11.parquet", header=True, inferSchema=True)
# df_2020_12 = spark.read.parquet("gs://msca-bdp-student-gcs/Group_8/fhvhv_tripdata_2019-12.parquet", header=True, inferSchema=True)


final_df_2019 = df_2019_02.union(df_2019_03).union(df_2019_04).union(df_2019_05).union(df_2019_06).union(df_2019_07).union(df_2019_08).union(df_2019_09).union(df_2019_010).union(df_2019_11).union(df_2019_12)

final_df_2019.show()

# df = spark.createDataFrame(df.rdd, ["PetalWidth","PetalLength","SepalWidth","SepalLength","Label"])
